# %%
from textgenrnn import textgenrnn

textgen = textgenrnn()
textgen.train_from_file('BernieSanders_tweets.txt', num_epochs=1)
textgen.generate()
# Out:
# 7,591 texts collected.
# Training on 667,874 character sequences.
# Epoch 1/1
# ...
